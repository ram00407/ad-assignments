# %%
Name="nafees fathima"

rollnumber = 456

height = 5.4

student = True

institution = "malla reddy university"

# %%
type(height)
# Out:
# float

# %%
type(student)
# Out:
# bool

# %%
type(Name)
# Out:
# str

# %%
type(rollnumber)
# Out:
# int

# %%
print(Name)
# Out:
# nafees fathima

# %%
print(5.4)
# Out:
# 5.4

# %%
a=9.56

a
# Out:
# 9.56

# %%
type(a)
# Out:
# float

# %%
int(a)
# Out:
# 9

# %%
y = int(a)

# %%
y
# Out:
# 9

# %%
a
# Out:
# 9.56

# %%
b=6

# %%
type(b)
# Out:
# int

# %%
float(b)
# Out:
# 6.0

# %%
y=float(b)

# %%
y
# Out:
# 6.0

# %%
b
# Out:
# 6

# %%
a+b
# Out:
# 15.56

# %%
x=a+b

x
# Out:
# 15.56

# %%
type(x)
# Out:
# float

# %%
str(b)
# Out:
# '6'

# %%
int(student)
# Out:
# 1

# %%
int(Name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a34f2306d663> in <cell line: 1>()
# ----> 1 int(Name)
#
# ValueError: invalid literal for int() with base 10: 'nafees fathima'

# %%
b+5
# Out:
# 11

# %%
x+6
# Out:
# 21.560000000000002

# %%
y+4
# Out:
# 10.0

# %%
r=str(b)

# %%
r
# Out:
# '6'

# %%
r+6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ef076705c4c9> in <cell line: 1>()
# ----> 1 r+6
#
# TypeError: can only concatenate str (not "int") to str

# %%
bool(Nafees)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1ab8b81664d5> in <cell line: 1>()
# ----> 1 bool(Nafees)
#
# NameError: name 'Nafees' is not defined

# %%
bool("nafees")
# Out:
# True

# %%
bool('  ')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
#Arthimatic operator
#addition +
#multiplication *
#subtraction -
#division /
#modulus %
#floor modulus //
#exponent **

# %%
a=12
b=4

# %%
a ** b
# Out:
# 20736

# %%
a + b
# Out:
# 16

# %%
a % b
# Out:
# 0

# %%
a ** 2
# Out:
# 144

# %%
a * 20
# Out:
# 240

# %%
a // b
# Out:
# 3

# %%
a / b
# Out:
# 3.0

# %%
a - b
# Out:
# 8

# %%
b - a
# Out:
# -8

# %%
#comparision operator
 #< > <= >= == !=

# %%
a>b
# Out:
# True

# %%
a=10
b=6

# %%
b>a
# Out:
# False

# %%
a==10
# Out:
# True

# %%
a!= b
# Out:
# True

# %%
a!=10
# Out:
# False

# %%
a>=10
# Out:
# True

# %%
a>10
# Out:
# False

# %%
(a>b) and (a<b)
# Out:
# False

# %%
(a>b) or (a<b)
# Out:
# True

# %%
not a>b
# Out:
# False

# %%
#logical operators
# and or not

# %%
True and True --- True
False and True --- False
True and False --- False
False and False --- False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
a>b and b>a
# Out:
# False

# %%
True or True --- True
False or True --- True
True or False --- True
False or False --- False
# Out:
# 0

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
x=46.24
y=24

# %%
s=x+y

# %%
type(s)
# Out:
# float

# %%
s=x+y

# %%
s
# Out:
# 70.24000000000001

# %%
#Q1
x=34.56
y=3.5
# all arhtimatic operators
# all logical operators
# all comparision opeator

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca730b97bf8a> in <cell line: 1>()
# ----> 1 a+b
#
# NameError: name 'a' is not defined

# %%
x=34.56
y=3.5

# %%
x+y
# Out:
# 38.06

# %%
x-y
# Out:
# 31.060000000000002

# %%
x**y
# Out:
# 242665.51770697304

# %%
x%y
# Out:
# 3.0600000000000023

# %%
(x>y) and (x<y)
# Out:
# False

# %%
(x>y) or (x<y)
# Out:
# True

# %%
not (x>y)
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
x!=y
# Out:
# True
